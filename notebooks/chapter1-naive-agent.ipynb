# %% [markdown]
# # Chapter 1: 「全部やって」の落とし穴
#
# このNotebookでは、1つのエージェントに記事全体を任せると、どんな問題が起きるかを体験します。
#
# ## 学習ポイント
# - 同じ指示でも、毎回違う結果が返ってくる不安定さ
# - 曖昧なinstructionsがもたらす品質のブレ
# - 「どこを直せばいいのか」が分からない状態

# %% [markdown]
# ## セットアップ
#
# 必要なパッケージをインストールします。

# %%
# Node.jsプロジェクトのセットアップ確認
# !cd .. && npm install

# %% [markdown]
# ## 環境変数の設定（OpenAI API使用時のみ）
#
# OpenAI APIを使用する場合は、`.env`ファイルに`OPENAI_API_KEY`を設定してください。
# AWS Bedrockを使用する場合は`.env`ファイルは不要です（IAM認証を使用）。

# %%
# %%bash
# # .envファイルの存在確認（OpenAI API使用時のみ必要）
# if [ ! -f ../.env ]; then
#     echo "⚠️  OpenAI APIを使用する場合は.envファイルが必要です"
#     echo "   cp ../.env.example ../.env"
#     echo "   （AWS Bedrockを使用する場合は不要です）"
# else
#     echo "✅ .envファイルが見つかりました"
# fi

# %% [markdown]
# ## Chapter 1の実行
#
# 単純なエージェントに「ブログ記事を書いてください」という曖昧な指示を2回送り、結果を比較します。

# %%
# %%bash
# cd .. && npm run ch1

# %% [markdown]
# ## 観察ポイント
#
# 上記の実行結果を確認して、以下の点に注目してください:
#
# 1. **構成の不安定性**: 見出しの数・順序が毎回変わっていないか？
# 2. **文字数のブレ**: 文字数・深さが安定しているか？
# 3. **対象読者の不明確さ**: 初心者向け？中級者向け？が明示されているか？
# 4. **修正の難しさ**: 何を修正すれば良いか、修正指示を出しやすいか？
#
# → これらが「曖昧なインプット」が生む問題です。
#
# **Chapter 2でタスクを分割して解決します。**

# %% [markdown]
# ## エージェントのコード
#
# 参考: このChapterで使用しているエージェントの定義

# %%
# %%bash
# cat ../src/chapter1/agent.ts

# %% [markdown]
# ## 次のステップ
#
# Chapter 2では、タスクを分割してワークフローを設計する方法を学びます。
#
# → `chapter2-workflow.ipynb`を開いてください。
