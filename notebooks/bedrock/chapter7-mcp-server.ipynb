# %% [markdown]
# # Chapter 7: MCP サーバーを作る 【Bedrock版】
#
# Chapter 5 で作ったツールを MCP (Model Context Protocol) サーバーとして公開し、クライアントから呼び出します。
#
# ※ MCP サーバーは LLM を使わないため、OpenAI/Bedrock の区別はありません。

# %% [markdown]
# ## セットアップ

# %%
import subprocess
def run(cmd):
    r = subprocess.run(cmd, shell=True, capture_output=True, text=True, cwd='../..')
    if r.stdout: print(r.stdout)
    if r.stderr: print(r.stderr)

run('echo "Node.js: $(node -v)" && npm install')

# %% [markdown]
# ## Chapter 7の実行
#
# MCPClient が server.ts を子プロセスとして起動し、ツールを呼び出します。

# %%
run('npm run ch7')

# %% [markdown]
# ## 観察ポイント
#
# 1. Chapter 5 のツール（`getCurrentDate`, `searchTopic`）がそのまま再利用されている
# 2. `MCPServer` + `startStdio()` だけで MCP サーバーが完成する
# 3. `MCPClient` から `listTools()` → `execute()` でツールを呼び出せる
# 4. Cursor / Windsurf / Claude Desktop 等の MCP クライアントからも接続可能
#
# ### MCP クライアントからの接続設定例
#
# ```json
# {
#   "mcpServers": {
#     "blog-research": {
#       "command": "npx",
#       "args": ["tsx", "src/chapter7/server.ts"],
#       "cwd": "/path/to/mastra-agent-tutorial"
#     }
#   }
# }
# ```

# %% [markdown]
# ## コード（参考）

# %%
run('echo "=== server.ts (MCP サーバー) ==="')
run('cat src/chapter7/server.ts')
run('echo "=== run.ts (デモクライアント) ==="')
run('cat src/chapter7/run.ts')

# %% [markdown]
# ## おわり
#
# お疲れさまでした！全チャプターが完了しました。
